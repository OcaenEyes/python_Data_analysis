# %% [markdown]
# ![image.png](attachment:4525f545-34d0-4e08-83e9-d62c20ad0ac6.png)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.font_manager import FontProperties
# Out:
# d:\programs\python\python36\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)

# %%
font = FontProperties(fname="../../simhei.ttf")

# %%
# %matplotlib inline

# %% [markdown]
# ![image.png](attachment:a6997f0f-c258-4283-9876-e5db44de3ef0.png)

# %% [markdown]
# ![image.png](attachment:9352e15c-5328-4e57-86b3-16786e7921db.png)

# %% [markdown]
# ![image.png](attachment:85139312-9aeb-4b8d-ac5f-9e2164a4aa0c.png)
