# %% [markdown]
# ![image.png](attachment:4525f545-34d0-4e08-83e9-d62c20ad0ac6.png)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.font_manager import FontProperties
# Out:
# d:\programs\python\python36\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)

# %%
font = FontProperties(fname="../../simhei.ttf")

# %%
# %matplotlib inline

# %% [markdown]
# ![image.png](attachment:a6997f0f-c258-4283-9876-e5db44de3ef0.png)

# %% [markdown]
# ![image.png](attachment:9352e15c-5328-4e57-86b3-16786e7921db.png)

# %% [markdown]
# ![image.png](attachment:64b7cee4-781a-4691-8397-4baeea20e0f7.png)

# %% [markdown]
# ![image.png](attachment:a0f4d7cd-164e-490d-970f-5f0ad581fb1a.png)

# %% [markdown]
# ![image.png](attachment:32aeb53e-8630-4e61-8e58-761f67caae00.png)

# %% [markdown]
# ![image.png](attachment:85139312-9aeb-4b8d-ac5f-9e2164a4aa0c.png)

# %% [markdown]
# ![image.png](attachment:2e2c95c3-6923-4c5b-845c-9af9e22eebf9.png)

# %% [markdown]
# ![image.png](attachment:6318135f-3841-4643-90e7-44f84a5a7b14.png)

# %% [markdown]
# ![image.png](attachment:433a17b2-3fc7-4003-b847-760632815428.png)

# %% [markdown]
# ![image.png](attachment:b0edf91f-2937-4bc5-abce-394e561b0594.png)

# %% [markdown]
# ![image.png](attachment:56b2b332-a4e7-4637-ac3c-6d60e35b9c87.png)
